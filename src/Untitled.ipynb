# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/historic_nfl_elo.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date  season  neutral playoff team1 team2  elo1_pre  \
# 0           0  1920-09-26    1920        0     NaN   RII   STP  1503.947
# 1           1  1920-10-03    1920        0     NaN   DAY   COL  1493.002
# 2           2  1920-10-03    1920        0     NaN   RII   MUN  1516.108
# 3           3  1920-10-03    1920        0     NaN   CHI   MUT  1368.333
# 4           4  1920-10-03    1920        0     NaN   CBD   PTQ  1504.688
#
#    elo2_pre  elo_prob1  ...  qbelo_prob1  qbelo_prob2  qb1_game_value  \
# 0  1300.000   0.824651  ...          NaN          NaN             NaN
# 1  1504.908   0.575819  ...          NaN          NaN             NaN
# 2  1478.004   0.644171  ...          NaN          NaN             NaN
# 3  1300.000   0.682986  ...          NaN          NaN             NaN
# 4  1300.000   0.825267  ...          NaN          NaN             NaN
#
#    qb2_game_value  qb1_value_post qb2_value_post qbelo1_post  qbelo2_post  \
# ...

# %%
df = df.loc[df["season"] >= 1970].iloc[:,1:]

# %%
df = df.drop(df.filter(regex='post').columns, axis=1).drop(df.filter(regex='team').columns, axis=1).drop(['playoff','qb1','qb2'],axis=1)

# %%
df.head()
# Out:
#             date  season  neutral  elo1_pre  elo2_pre  elo_prob1  elo_prob2  \
# 4549  1970-09-18    1970        0  1583.202  1426.127   0.782172   0.217828
# 4550  1970-09-19    1970        0  1475.119  1382.173   0.712839   0.287161
# 4551  1970-09-20    1970        0  1396.972  1638.776   0.265463   0.734537
# 4552  1970-09-20    1970        0  1458.876  1488.866   0.550214   0.449786
# 4553  1970-09-20    1970        0  1386.799  1436.731   0.521671   0.478329
#
#        qbelo1_pre   qbelo2_pre  qb1_value_pre  qb2_value_pre    qb1_adj  \
# 4549  1575.663197  1419.063694     128.244691      49.900901   3.032010
# 4550  1468.322928  1392.110372     157.629495      62.866097  10.160311
# 4551  1395.779057  1634.838107      71.546016     134.503032  -3.150676
# 4552  1462.726939  1484.068018     125.979821     149.501039   9.231151
# 4553  1369.469608  1428.578167     -13.376009      25.344557 -19.863256
#
# ...
